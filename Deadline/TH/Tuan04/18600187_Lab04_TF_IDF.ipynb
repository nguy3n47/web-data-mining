# %% [markdown]
# # Lab04: TF-IDF.
#
# - MSSV: 18600187
# - Họ và tên: Vũ Cao Nguyên

# %% [markdown]
# ## Yêu cầu bài tập
#
# **Cách làm bài**
#
#
# Bạn sẽ làm trực tiếp trên file notebook này; từ `TODO` cho biết những phần mà bạn cần phải làm.
#
# Bạn có thể thảo luận ý tưởng cũng như tham khảo các tài liệu, nhưng *code và bài làm phải là của bạn*.
#
# Nếu vi phạm thì sẽ bị 0 điểm cho bài tập này.
#
# **Cách nộp bài**
#
# Trước khi nộp bài, rerun lại notebook (`Kernel` -> `Restart & Run All`).
#
# Sau đó, tạo thư mục có tên `MSSV` của bạn (vd, nếu bạn có MSSV là 1234567 thì bạn đặt tên thư mục là `1234567`) Chép file notebook, file `tf_idf_data.txt` của các bạn (nếu file này kích thước lớn các bạn có thể chép link vào `link_data.txt`), nén thư mục `MSSV` này lại và nộp trên moodle.
#
# **Nội dung bài tập**
#
# Cài đặt một web crawler để thu thập và biểu diễn dữ liệu bằng không gian vector và trọng số TF-IDF: https://en.wikipedia.org/wiki/Web_mining.

# %% [markdown]
# ## Nội dung bài tập

# %% [markdown]
# ## 1. Không gian vector

# %% [markdown]
# - Một vector 2 chiều có thể được viết dưới dạng `[x,y]`
# - Một vector 3 chiều có thể được viết dưới dạng `[x,y,z]`
# ![vector](vector.png)

# %% [markdown]
# - Đặt $V$ là tập hợp các đặc trưng trong thể hiện dữ liệu.
# - Bất kỳ mẫu dữ liệu nào đều có thể được biểu diễn dưới dạng một vectơ với $\vert V\vert$ chiều
# - Ví dụ: giả sử chúng ta có 3 đặc trưng là các từ dog, bite, man. Giá trị 1 thể hiện từ đó xuất hiện 1 lần, 0 là không xuất hiện.
# ![space](space.png)

# %% [markdown]
# ## 2. TF-IDF (Term Frequency - Inverse Document Frequency)
# TF-IDF cho biết độ quan trọng của một từ đối với một tài liệu trong ngữ liệu.
#
# TF- Term Frequency : dùng để ước lượng tần xuất xuất hiện của từ trong văn bản. Tuy nhiên với mỗi văn bản thì có độ dài khác nhau số lần xuất hiện của từ có thể nhiều hơn . Vì vậy số lần xuất hiện của từ sẽ được chuẩn hóa bằng cách chia cho độ dài của văn bản (tổng số từ trong văn bản đó).
#
# $$tf_{t}=\dfrac{f(t,d)}{\sum_{i \in d}f(i,d)}$$
#
# - $f(t,d)$ là số lần xuất hiện từ $t$ trong văn bản $d$.
#
# IDF- Inverse Document Frequency: Khi tính tần số xuất hiện TF thì các từ đều được coi là quan trọng như nhau. Tuy nhiên có một số từ thường được được sử dụng nhiều nhưng không quan trọng để thể hiện ý nghĩa của đoạn văn như "is", "the"... (các từ chức năng). Ta cần giảm độ quan trọng của những từ này.
#
# $$idf_t=\log \left(\dfrac{n}{df_t}\right)$$
#
# - *n* là số văn bản.
#
# - $df_t$ là số văn bản xuất hiện từ t
#
# **TF-IDF:** $$tf_{t} \times idf_t$$
#
# - $tf_{t}$ càng lớn tần suất xuất hiện của từ trong văn bản càng lớn.
# - $idf_t$ càng lớn từ hiếm khi xuất hiện trong tập dữ liệu.
# - **Giả định** những đặc trưng quan trọng nhất là những đặc trưng hiếm xuất hiện.

# %% [markdown]
# ## 3. Thu thập và thể hiện dữ liệu
# Thu thập dữ liệu bắt đầu từ URL: https://en.wikipedia.org/wiki/Web_mining.
# - Gọi $D$ là một tập văn bản chứa *n* văn bản: $D=\left\{d_1,d_2,...,d_n\right\}$.
# - $V=\left\{v_1,v_2,...v_{\vert V \vert}\right\}$ là từ điển (tất cả các từ phân biệt trong dữ liệu thu được). $\vert V \vert$ là kích thước từ điển.
# - Một trọng số $w_{ij}$ được gán cho từ $t_i$ của văn bản dj thuộc $D$ xác định mức quan trọng của $t_i$ trong văn bản $d_j$. Từ không xuất hiện trong $d_j$ có $w_{ij}=0$.
# - Mỗi văn bản $d_j$ được thể hiện dưới dạng vector $\mathbf{d_j}= [w_{1j},w_{2j},...,w_{\vert V \vert j}]$
# - Thể hiện dữ liệu bằng một ma trận M kích thước $n \times \vert V \vert$ => mỗi hàng thể hiện một văn bản.

# %%
import requests
import re
from bs4 import BeautifulSoup
from bs4.element import Comment
import string
import pickle
import urllib.robotparser

rp = urllib.robotparser.RobotFileParser()
rp.set_url("https://en.wikipedia.org/robots.txt")
rp.read()
rrate = rp.request_rate("*")

rp.crawl_delay("*")

def get_urls(url):
    r = requests.get(url)
    urls = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', r.text) 
    urls_copy = urls.copy()
    for url in urls_copy:
      if(rp.can_fetch("*", url) == False):
        urls.remove(url)
    return urls

def get_urls_recursive(start_url, limit):
    urls = get_urls(start_url)
    for url in urls:
        if(len(urls) >= limit):
            return urls[:limit]
        new_urls = get_urls(url)
        for new_url in new_urls:
          if(new_url not in urls and len(urls) < limit):
            urls.append(new_url)
    return urls[:limit]
url_list = get_urls_recursive('https://en.wikipedia.org/wiki/Web_mining', 3)
print((url_list))
print(len(url_list))
# Out:
# ['https://en.wikipedia.org/wiki/Web_mining', 'https://archive.org/details/webinformationsy00ngua', 'https://archive.org/details/webinformationsy00ngua/page/n33']
# 3

# %%
def text_filter(element):
    if element.parent.name in ['style', 'title', 'script', 'head', '[document]', 'class', 'a', 'li']:
        return False
    elif isinstance(element, Comment):
        '''Opinion mining?'''
        return False
    elif re.match(r"[\s\r\n]+",str(element)): 
        '''space, return, endline'''
        return False
    return True

# %%
def wordList(url):
    r=requests.get(url)
    soup=BeautifulSoup(r.content,"html.parser")
    text=soup.findAll(text=True)
    filtered_text=list(filter(text_filter,text))
    word_list=[]
    for astring in filtered_text:
      for types in string.punctuation:
        astring=astring.replace(types,' ')
        word_list.extend(astring.split(' '))
        word_list=[astr for astr in word_list if astr not in ' \n']
    return word_list

# %%
def read_url(url):
    word_list=wordList(url)
    result=[]
    for word in word_list:
      word = word.lower()
      if word not in result:
        result.append(word)
     
    return result

# %%
data = set()
new_list=[];
for url in url_list:
    word_list = read_url(url)
    new_list.append(word_list)
    data = data.union(set(word_list))

# %%
import numpy as np
W = np.array(new_list, dtype=object)
print(W[0])
# Out:
# ['web', 'mining', 'from', 'wikipedia,', 'the', 'free', 'encyclopedia', 'wikipedia', 'this', 'article', 'includes', 'a', ',', 'related', 'reading', 'or', 'but', 'its', 'sources', 'remain', 'unclear', 'because', 'it', 'lacks', '.', '(', 'october', '2020', ')', 'may', 'require', 'specific', 'problem', 'is:', 'is', 'needs', 'sufficient', 'inline', 'references,', 'and', 'complete', 're-write', 'has', 'been', 'proposed.', 'references', 're', 'write', 'proposed', 'uses', 'automated', 'methods', 'to', 'extract', 'both', 'structured', 'unstructured', 'data', 'pages,', 'server', 'logs', 'link', 'structures.', 'there', 'are', 'three', 'main', 'sub-categories', 'of', 'mining.', 'pages', 'sub', 'categories', 'structures', 'contents', '1', 'types', '2', 'usage', '2.1', 'pros', '2.2', 'cons', '3', 'structure', '4', 'content', '4.1', 'in', 'foreign', 'languages', '4.1.1', 'chinese', '5', 'see', 'also', '6', '6.1', 'books', '6.2', 'bibliographic', '[', ']', 'can', 'be', 'divided', 'into', 'different', '–', '.\n', 'general', 'relationship', 'between', 'objectives', 'comparison', 'mining\n', 'ir', 'view\n', 'db', 'view', 'data\n', 'representation\n', 'method\n', 'application', 'categories\n', '.\nusage', 'captures', 'identity', 'origin', 'users', 'along', 'with', 'their', 'browsing', 'behavior', 'at', 'site.\n', '\nusage', 'site', 'itself', 'classified', 'further', 'depending', 'on', 'kind', 'considered:\n', 'considered', 'level', 'studies', 'work', 'essentially', 'many', 'advantages', 'which', 'makes', 'technology', 'attractive', 'corporations', 'including', 'government', 'agencies.', 'enabled', 'agencies', 'eventually', 'results', 'higher', 'trade', 'volumes.', 'using', 'classify', 'threats', 'volumes', 'predicting', 'capability', 'applications', 'benefit', 'society', 'by', 'identifying', 'criminal', 'activities.', 'companies', 'establish', 'better', 'activities', 'more', 'benefits', 'mining,', 'particularly', 'area', 'outlined', 'frameworks', 'such', 'as', 'does', 'not', 'create', 'issues,', 'when', 'used', 'issues', 'privacy', 'lost', 'information', 'concerning', 'an', 'individual', 'obtained,', 'used,', 'disseminated,', 'especially', 'if', 'occurs', 'without', "individual's", 'knowledge', 'consent.', 's', 'obtained', 'disseminated', 'consent', 'then', 'another', 'important', 'concern', 'that', 'collecting', 'for', 'purpose', 'might', 'use', 'totally', 'purposes,', 'violates', "user's", 'interests.\n', 'user', 'purposes', 'interests', 'growing', 'trend', 'selling', 'personal', 'commodity', 'encourages', 'website', 'owners', 'site.', 'increased', 'amount', 'being', 'captured', 'traded', 'increasing', 'likeliness', "one's", 'invaded.', 'buy', 'obliged', 'make', 'anonymous', 'these', 'authors', 'any', 'release', 'patterns.', 'they', 'legally', 'responsible', 'release;', 'inaccuracies', 'will', 'result', 'serious', 'lawsuits,', 'no', 'law', 'preventing', 'them', 'trading', 'data.\n', 'one', 'lawsuits', 'invaded', 'patterns', 'some', 'algorithms', 'controversial', 'attributes', 'like', 'sex,', 'race,', 'religion,', 'sexual', 'orientation', 'categorize', 'individuals.', 'practices', 'against', 'anti-discrimination', 'legislation.', 'sex', 'race', 'religion', 'anti', 'discrimination', 'individuals', 'legislation', 'section', 'expansion', 'you', 'help', 'june', '2015', 'appropriate.', 'appropriate', 'terminology:\n', 'terminology', 'example', 'techniques', 'extraction', 'integration', 'useful', 'data,', 'page', 'content.', 'heterogeneity', 'others', 'provide', 'comfort', 'users,', 'do', 'generally', 'structural', 'nor', 'categorize,', 'filter,', 'interpret', 'documents.', 'factors', 'have', 'prompted', 'researchers', 'develop', 'intelligent', 'tools', 'filter', 'documents', 'well', 'extend', 'database', 'organization', 'differentiated', 'two', 'points', 'view:', 'several', 'ways', 'represent', 'documents;', 'multi-scanning', 'document,', 'we', 'implement', 'feature', 'selection.', 'under', 'condition', 'category', 'rarely', 'affected,', 'subset', 'n ...

# %%
def count(words):
  dictionary = dict.fromkeys(data, 0)
  for word in words:
    dictionary[word]+=1
  return dictionary

# %%
# TF
def calculateTF(dictionary, words):
    tfDictionary = {}
    wordsCount = len(words)
    for word, count in dictionary.items():
        tfDictionary[word] = count/float(wordsCount)
    return tfDictionary

# %%
# IDF
def calculateIDF(document_list):
    import math
    idfDictionary = {}
    N = len(document_list) 
    idfDictionary = dict.fromkeys(document_list[0].keys(), 0)
    for doc in document_list:
        for word, val in doc.items():
            if val > 0:
                idfDictionary[word] += 1
    for word, val in idfDictionary.items():
        idfDictionary[word] = math.log10(N / float(val))
        
    return idfDictionary

# %%
def calculateTFxIDF(tfs, idfs):
    tfxidf = {}
    for word, val in tfs.items():
        tfxidf[word] = val*idfs[word]
    return tfxidf

# %%
listTF=[];
for words in W:
  wordConut=count(words)
  tfdoc = calculateTF(wordConut, words)
  listTF.append(tfdoc)

# %%
idfs = calculateIDF(listTF)
print(idfs)
# Out:
# {'semantic': 0.17609125905568124, 'related-external-id': 0.17609125905568124, 'engineering,': 0.17609125905568124, 'navigation': 0.47712125471966244, ':': 0.0, 'sheng,': 0.47712125471966244, 'on': 0.0, 'book': 0.17609125905568124, 'pa:': 0.47712125471966244, 'ngu,': 0.47712125471966244, 'short': 0.17609125905568124, 'pernul,': 0.47712125471966244, 'dhakal,': 0.47712125471966244, ',': 0.0, 'explorations': 0.47712125471966244, 'provide': 0.47712125471966244, 'invaded.': 0.47712125471966244, 'categorize,': 0.47712125471966244, 'reddit': 0.17609125905568124, 'vries': 0.47712125471966244, 'without': 0.47712125471966244, 'methodology': 0.17609125905568124, 'index\n': 0.17609125905568124, 'façade': 0.17609125905568124, 'topical': 0.17609125905568124, 'mining:': 0.47712125471966244, 'category': 0.47712125471966244, 'e-commerce,': 0.17609125905568124, '2007).': 0.47712125471966244, '07': 0.17609125905568124, 'it': 0.47712125471966244, '18': 0.17609125905568124, 'responsible': 0.47712125471966244, 'toggled': 0.17609125905568124, 'interpret': 0.47712125471966244, 'of': 0.0, 'contribute': 0.47712125471966244, 'factors': 0.47712125471966244, '|journal=': 0.47712125471966244, 'you': 0.47712125471966244, 'software': 0.17609125905568124, '&': 0.47712125471966244, '14': 0.17609125905568124, 'wordpress': 0.17609125905568124, 'technical': 0.47712125471966244, 'sexual': 0.47712125471966244, 'recommendation': 0.17609125905568124, 'both': 0.47712125471966244, 'does': 0.47712125471966244, 'several': 0.47712125471966244, 'et': 0.47712125471966244, 'variants': 0.47712125471966244, 'circle': 0.17609125905568124, 'height=384': 0.17609125905568124, 'preventing': 0.47712125471966244, 'release': 0.47712125471966244, 'will': 0.47712125471966244, 'download': 0.17609125905568124, 'kurt': 0.47712125471966244, 'e': 0.17609125905568124, 'encourages': 0.47712125471966244, 'advantages': 0.47712125471966244, 'trade': 0.47712125471966244, 'multi': 0.47712125471966244, 'façade.': 0.17609125905568124, 'head': 0.17609125905568124, 'services': 0.17609125905568124, 'speirs,': 0.47712125471966244, 'publication': 0.17609125905568124, 'consent.': 0.47712125471966244, 'industrial': 0.17609125905568124, 'open': 0.17609125905568124, '(15': 0.47712125471966244, 'considered:\n': 0.47712125471966244, '2005934894': 0.17609125905568124, 'rodrick': 0.47712125471966244, 'publishing': 0.47712125471966244, 'inner': 0.47712125471966244, '2011': 0.17609125905568124, 'an': 0.0, 'foreign': 0.47712125471966244, 'archiveorg': 0.17609125905568124, 'p2p,': 0.17609125905568124, 'glass.': 0.17609125905568124, 'under': 0.47712125471966244, 'structure,': 0.17609125905568124, 'kind': 0.47712125471966244, 'them': 0.47712125471966244, 'over': 0.17609125905568124, 'item': 0.17609125905568124, 'law': 0.47712125471966244, 'concern': 0.47712125471966244, 'yan.': 0.47712125471966244, 'etc': 0.17609125905568124, 'denise': 0.47712125471966244, 'activities': 0.47712125471966244, 'management': 0.17609125905568124, 'such': 0.47712125471966244, '2019': 0.47712125471966244, 'concerning': 0.47712125471966244, 'data\n': 0.47712125471966244, 'they': 0.47712125471966244, 'complete': 0.47712125471966244, "person's": 0.17609125905568124, '(pdf)': 0.47712125471966244, 'languages': 0.47712125471966244, 'web': 0.0, 'oclc': 0.17609125905568124, 'edition)': 0.17609125905568124, '4-6,': 0.47712125471966244, 'into': 0.47712125471966244, 'uses': 0.47712125471966244, 'method,': 0.17609125905568124, 'captured': 0.47712125471966244, '22': 0.17609125905568124, '.\nusage': 0.47712125471966244, 'categories:': 0.47712125471966244, 'submissions': 0.17609125905568124, 'selection.': 0.47712125471966244, 'patterns': 0.47712125471966244, 'illustration': 0.17609125905568124, 'method': 0.17609125905568124, 'are': 0.0, '978-1591404149': 0.47712125471966244, 'make': 0.47712125471966244, 'buy': 0.47712125471966244, 'requires': 0.47712125471966244, 'work': 0.0, 'methodology,': 0.17609125905568124, 'with': 0.0, 'addeddate': 0.17609125905568124, ...

# %%
sum_list=[]
for tfs in listTF:
  tfxidf = calculateTFxIDF(tfs, idfs)
  print(tfxidf)
  sum_list.append(tfxidf)
# Out:
# {'semantic': 0.0, 'related-external-id': 0.0, 'engineering,': 0.0, 'navigation': 0.0008100530640401739, ':': 0.0, 'sheng,': 0.0008100530640401739, 'on': 0.0, 'book': 0.0, 'pa:': 0.0008100530640401739, 'ngu,': 0.0008100530640401739, 'short': 0.0, 'pernul,': 0.0008100530640401739, 'dhakal,': 0.0008100530640401739, ',': 0.0, 'explorations': 0.0008100530640401739, 'provide': 0.0008100530640401739, 'invaded.': 0.0008100530640401739, 'categorize,': 0.0008100530640401739, 'reddit': 0.0, 'vries': 0.0008100530640401739, 'without': 0.0008100530640401739, 'methodology': 0.0, 'index\n': 0.0, 'façade': 0.0, 'topical': 0.0, 'mining:': 0.0008100530640401739, 'category': 0.0008100530640401739, 'e-commerce,': 0.0, '2007).': 0.0008100530640401739, '07': 0.0, 'it': 0.0008100530640401739, '18': 0.0, 'responsible': 0.0008100530640401739, 'toggled': 0.0, 'interpret': 0.0008100530640401739, 'of': 0.0, 'contribute': 0.0008100530640401739, 'factors': 0.0008100530640401739, '|journal=': 0.0008100530640401739, 'you': 0.0008100530640401739, 'software': 0.0, '&': 0.0008100530640401739, '14': 0.0, 'wordpress': 0.0, 'technical': 0.0008100530640401739, 'sexual': 0.0008100530640401739, 'recommendation': 0.0, 'both': 0.0008100530640401739, 'does': 0.0008100530640401739, 'several': 0.0008100530640401739, 'et': 0.0008100530640401739, 'variants': 0.0008100530640401739, 'circle': 0.0, 'height=384': 0.0, 'preventing': 0.0008100530640401739, 'release': 0.0008100530640401739, 'will': 0.0008100530640401739, 'download': 0.0, 'kurt': 0.0008100530640401739, 'e': 0.0, 'encourages': 0.0008100530640401739, 'advantages': 0.0008100530640401739, 'trade': 0.0008100530640401739, 'multi': 0.0008100530640401739, 'façade.': 0.0, 'head': 0.0, 'services': 0.0, 'speirs,': 0.0008100530640401739, 'publication': 0.0, 'consent.': 0.0008100530640401739, 'industrial': 0.0, 'open': 0.0, '(15': 0.0008100530640401739, 'considered:\n': 0.0008100530640401739, '2005934894': 0.0, 'rodrick': 0.0008100530640401739, 'publishing': 0.0008100530640401739, 'inner': 0.0008100530640401739, '2011': 0.0, 'an': 0.0, 'foreign': 0.0008100530640401739, 'archiveorg': 0.0, 'p2p,': 0.0, 'glass.': 0.0, 'under': 0.0008100530640401739, 'structure,': 0.0, 'kind': 0.0008100530640401739, 'them': 0.0008100530640401739, 'over': 0.0, 'item': 0.0, 'law': 0.0008100530640401739, 'concern': 0.0008100530640401739, 'yan.': 0.0008100530640401739, 'etc': 0.0, 'denise': 0.0008100530640401739, 'activities': 0.0008100530640401739, 'management': 0.0, 'such': 0.0008100530640401739, '2019': 0.0008100530640401739, 'concerning': 0.0008100530640401739, 'data\n': 0.0008100530640401739, 'they': 0.0008100530640401739, 'complete': 0.0008100530640401739, "person's": 0.0, '(pdf)': 0.0008100530640401739, 'languages': 0.0008100530640401739, 'web': 0.0, 'oclc': 0.0, 'edition)': 0.0, '4-6,': 0.0008100530640401739, 'into': 0.0008100530640401739, 'uses': 0.0008100530640401739, 'method,': 0.0, 'captured': 0.0008100530640401739, '22': 0.0, '.\nusage': 0.0008100530640401739, 'categories:': 0.0008100530640401739, 'submissions': 0.0, 'selection.': 0.0008100530640401739, 'patterns': 0.0008100530640401739, 'illustration': 0.0, 'method': 0.0, 'are': 0.0, '978-1591404149': 0.0008100530640401739, 'make': 0.0008100530640401739, 'buy': 0.0008100530640401739, 'requires': 0.0008100530640401739, 'work': 0.0, 'methodology,': 0.0, 'with': 0.0, 'addeddate': 0.0, 'evaluate': 0.0008100530640401739, 'twitter': 0.0, 'film': 0.0, 'language': 0.0, 'sex': 0.0008100530640401739, '3.5': 0.0, 'we': 0.0008100530640401739, 'estivill-castro;': 0.0008100530640401739, 'frameborder=0': 0.0, 'government': 0.0008100530640401739, 'needed.': 0.0008100530640401739, 'these': 0.0008100530640401739, 'needed': 0.0008100530640401739, 'sessions': 0.0, 'if': 0.0008100530640401739, 'purposes': 0.0008100530640401739, 'website': 0.0008100530640401739, 'also': 0.0008100530640401739, 'strip.': 0.0, 'person': 0.0, 'were': 0.0, 'subset': 0.0008100530640401739, 'carefully': 0.0, 'occurs': 0.00081005306404 ...
# {'semantic': 0.0004798126949746083, 'related-external-id': 0.0004798126949746083, 'engineering,': 0.0004798126949746083, 'navigation': 0.0, ':': 0.0, 'sheng,': 0.0, 'on': 0.0, 'book': 0.0004798126949746083, 'pa:': 0.0, 'ngu,': 0.0, 'short': 0.0004798126949746083, 'pernul,': 0.0, 'dhakal,': 0.0, ',': 0.0, 'explorations': 0.0, 'provide': 0.0, 'invaded.': 0.0, 'categorize,': 0.0, 'reddit': 0.0004798126949746083, 'vries': 0.0, 'without': 0.0, 'methodology': 0.0004798126949746083, 'index\n': 0.0004798126949746083, 'façade': 0.0004798126949746083, 'topical': 0.0004798126949746083, 'mining:': 0.0, 'category': 0.0, 'e-commerce,': 0.0004798126949746083, '2007).': 0.0, '07': 0.0004798126949746083, 'it': 0.0, '18': 0.0004798126949746083, 'responsible': 0.0, 'toggled': 0.0004798126949746083, 'interpret': 0.0, 'of': 0.0, 'contribute': 0.0, 'factors': 0.0, '|journal=': 0.0, 'you': 0.0, 'software': 0.0004798126949746083, '&': 0.0, '14': 0.0004798126949746083, 'wordpress': 0.0004798126949746083, 'technical': 0.0, 'sexual': 0.0, 'recommendation': 0.0004798126949746083, 'both': 0.0, 'does': 0.0, 'several': 0.0, 'et': 0.0, 'variants': 0.0, 'circle': 0.0004798126949746083, 'height=384': 0.0004798126949746083, 'preventing': 0.0, 'release': 0.0, 'will': 0.0, 'download': 0.0004798126949746083, 'kurt': 0.0, 'e': 0.0004798126949746083, 'encourages': 0.0, 'advantages': 0.0, 'trade': 0.0, 'multi': 0.0, 'façade.': 0.0004798126949746083, 'head': 0.0004798126949746083, 'services': 0.0004798126949746083, 'speirs,': 0.0, 'publication': 0.0004798126949746083, 'consent.': 0.0, 'industrial': 0.0004798126949746083, 'open': 0.0004798126949746083, '(15': 0.0, 'considered:\n': 0.0, '2005934894': 0.0004798126949746083, 'rodrick': 0.0, 'publishing': 0.0, 'inner': 0.0, '2011': 0.0004798126949746083, 'an': 0.0, 'foreign': 0.0, 'archiveorg': 0.0004798126949746083, 'p2p,': 0.0004798126949746083, 'glass.': 0.0004798126949746083, 'under': 0.0, 'structure,': 0.0004798126949746083, 'kind': 0.0, 'them': 0.0, 'over': 0.0004798126949746083, 'item': 0.0004798126949746083, 'law': 0.0, 'concern': 0.0, 'yan.': 0.0, 'etc': 0.0004798126949746083, 'denise': 0.0, 'activities': 0.0, 'management': 0.0004798126949746083, 'such': 0.0, '2019': 0.0, 'concerning': 0.0, 'data\n': 0.0, 'they': 0.0, 'complete': 0.0, "person's": 0.0004798126949746083, '(pdf)': 0.0, 'languages': 0.0, 'web': 0.0, 'oclc': 0.0004798126949746083, 'edition)': 0.0004798126949746083, '4-6,': 0.0, 'into': 0.0, 'uses': 0.0, 'method,': 0.0004798126949746083, 'captured': 0.0, '22': 0.0004798126949746083, '.\nusage': 0.0, 'categories:': 0.0, 'submissions': 0.0004798126949746083, 'selection.': 0.0, 'patterns': 0.0, 'illustration': 0.0004798126949746083, 'method': 0.0004798126949746083, 'are': 0.0, '978-1591404149': 0.0, 'make': 0.0, 'buy': 0.0, 'requires': 0.0, 'work': 0.0, 'methodology,': 0.0004798126949746083, 'with': 0.0, 'addeddate': 0.0004798126949746083, 'evaluate': 0.0, 'twitter': 0.0004798126949746083, 'film': 0.0004798126949746083, 'language': 0.0004798126949746083, 'sex': 0.0, '3.5': 0.0004798126949746083, 'we': 0.0, 'estivill-castro;': 0.0, 'frameborder=0': 0.0004798126949746083, 'government': 0.0, 'needed.': 0.0, 'these': 0.0, 'needed': 0.0, 'sessions': 0.0004798126949746083, 'if': 0.0, 'purposes': 0.0, 'website': 0.0, 'also': 0.0, 'strip.': 0.0004798126949746083, 'person': 0.0004798126949746083, 'were': 0.0004798126949746083, 'subset': 0.0, 'carefully': 0.0004798126949746083, 'occurs': 0.0, 'hidden': 0.0, 'openlibrary_edition': 0.0004798126949746083, 'categories': 0.0, 'a.': 0.0, 'description': 0.0004798126949746083, 'urn:oclc:318289885': 0.0004798126949746083, 'collections': 0.0004798126949746083, '2000': 0.0, 'needs': 0.0, 'hendrik': 0.0, 'donate': 0.0004798126949746083, 'kirsten': 0.0, "individual's": 0.0, '(2007).': 0.0, 'publisher': 0.0004798126949746083, 'see': 0.0, 'data,': 0.0, 'f': 0.0, 'content.': 0.0, 'companies': 0.0, 'retrieved': 0.0, 'technology': 0.0, 'publications,': 0.0, 'email': 0.000479812694974 ...
# {'semantic': 0.0004798126949746083, 'related-external-id': 0.0004798126949746083, 'engineering,': 0.0004798126949746083, 'navigation': 0.0, ':': 0.0, 'sheng,': 0.0, 'on': 0.0, 'book': 0.0004798126949746083, 'pa:': 0.0, 'ngu,': 0.0, 'short': 0.0004798126949746083, 'pernul,': 0.0, 'dhakal,': 0.0, ',': 0.0, 'explorations': 0.0, 'provide': 0.0, 'invaded.': 0.0, 'categorize,': 0.0, 'reddit': 0.0004798126949746083, 'vries': 0.0, 'without': 0.0, 'methodology': 0.0004798126949746083, 'index\n': 0.0004798126949746083, 'façade': 0.0004798126949746083, 'topical': 0.0004798126949746083, 'mining:': 0.0, 'category': 0.0, 'e-commerce,': 0.0004798126949746083, '2007).': 0.0, '07': 0.0004798126949746083, 'it': 0.0, '18': 0.0004798126949746083, 'responsible': 0.0, 'toggled': 0.0004798126949746083, 'interpret': 0.0, 'of': 0.0, 'contribute': 0.0, 'factors': 0.0, '|journal=': 0.0, 'you': 0.0, 'software': 0.0004798126949746083, '&': 0.0, '14': 0.0004798126949746083, 'wordpress': 0.0004798126949746083, 'technical': 0.0, 'sexual': 0.0, 'recommendation': 0.0004798126949746083, 'both': 0.0, 'does': 0.0, 'several': 0.0, 'et': 0.0, 'variants': 0.0, 'circle': 0.0004798126949746083, 'height=384': 0.0004798126949746083, 'preventing': 0.0, 'release': 0.0, 'will': 0.0, 'download': 0.0004798126949746083, 'kurt': 0.0, 'e': 0.0004798126949746083, 'encourages': 0.0, 'advantages': 0.0, 'trade': 0.0, 'multi': 0.0, 'façade.': 0.0004798126949746083, 'head': 0.0004798126949746083, 'services': 0.0004798126949746083, 'speirs,': 0.0, 'publication': 0.0004798126949746083, 'consent.': 0.0, 'industrial': 0.0004798126949746083, 'open': 0.0004798126949746083, '(15': 0.0, 'considered:\n': 0.0, '2005934894': 0.0004798126949746083, 'rodrick': 0.0, 'publishing': 0.0, 'inner': 0.0, '2011': 0.0004798126949746083, 'an': 0.0, 'foreign': 0.0, 'archiveorg': 0.0004798126949746083, 'p2p,': 0.0004798126949746083, 'glass.': 0.0004798126949746083, 'under': 0.0, 'structure,': 0.0004798126949746083, 'kind': 0.0, 'them': 0.0, 'over': 0.0004798126949746083, 'item': 0.0004798126949746083, 'law': 0.0, 'concern': 0.0, 'yan.': 0.0, 'etc': 0.0004798126949746083, 'denise': 0.0, 'activities': 0.0, 'management': 0.0004798126949746083, 'such': 0.0, '2019': 0.0, 'concerning': 0.0, 'data\n': 0.0, 'they': 0.0, 'complete': 0.0, "person's": 0.0004798126949746083, '(pdf)': 0.0, 'languages': 0.0, 'web': 0.0, 'oclc': 0.0004798126949746083, 'edition)': 0.0004798126949746083, '4-6,': 0.0, 'into': 0.0, 'uses': 0.0, 'method,': 0.0004798126949746083, 'captured': 0.0, '22': 0.0004798126949746083, '.\nusage': 0.0, 'categories:': 0.0, 'submissions': 0.0004798126949746083, 'selection.': 0.0, 'patterns': 0.0, 'illustration': 0.0004798126949746083, 'method': 0.0004798126949746083, 'are': 0.0, '978-1591404149': 0.0, 'make': 0.0, 'buy': 0.0, 'requires': 0.0, 'work': 0.0, 'methodology,': 0.0004798126949746083, 'with': 0.0, 'addeddate': 0.0004798126949746083, 'evaluate': 0.0, 'twitter': 0.0004798126949746083, 'film': 0.0004798126949746083, 'language': 0.0004798126949746083, 'sex': 0.0, '3.5': 0.0004798126949746083, 'we': 0.0, 'estivill-castro;': 0.0, 'frameborder=0': 0.0004798126949746083, 'government': 0.0, 'needed.': 0.0, 'these': 0.0, 'needed': 0.0, 'sessions': 0.0004798126949746083, 'if': 0.0, 'purposes': 0.0, 'website': 0.0, 'also': 0.0, 'strip.': 0.0004798126949746083, 'person': 0.0004798126949746083, 'were': 0.0004798126949746083, 'subset': 0.0, 'carefully': 0.0004798126949746083, 'occurs': 0.0, 'hidden': 0.0, 'openlibrary_edition': 0.0004798126949746083, 'categories': 0.0, 'a.': 0.0, 'description': 0.0004798126949746083, 'urn:oclc:318289885': 0.0004798126949746083, 'collections': 0.0004798126949746083, '2000': 0.0, 'needs': 0.0, 'hendrik': 0.0, 'donate': 0.0004798126949746083, 'kirsten': 0.0, "individual's": 0.0, '(2007).': 0.0, 'publisher': 0.0004798126949746083, 'see': 0.0, 'data,': 0.0, 'f': 0.0, 'content.': 0.0, 'companies': 0.0, 'retrieved': 0.0, 'technology': 0.0, 'publications,': 0.0, 'email': 0.000479812694974 ...

# %%
import numpy as np
M=np.zeros(shape=(len(sum_list),len(sum_list[0])),dtype=float)
i = 0
for sum in sum_list:
  j=0
  for word, val in sum.items():
    M[i][j]=val
    j+=1
  i+=1
print(M)
# Out:
# [[0.         0.         0.         ... 0.         0.00081005 0.        ]
#  [0.00047981 0.00047981 0.00047981 ... 0.00047981 0.         0.00047981]
#  [0.00047981 0.00047981 0.00047981 ... 0.00047981 0.         0.00047981]]

# %%
from google.colab import drive
drive.mount('/content/drive')
np.savetxt("/content/drive/My Drive/Colab Notebooks/18600187.txt", M, fmt="%s")
